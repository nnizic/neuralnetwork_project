# %% [markdown]
# <h1>CNN modeli za prepoznavanje šalica</h1>
# <hr/>
# <h2>Model Bravo</h2>
# <p>Testovi sa promjenama broja epoha i veličine batcheva</p>
# <p> Nakon testova i loših rezultata validacije na setu slika 700/100 po klasi, (MOdel Alfa) , pokušat ćes se poboljšati rezultati povećanjem broja slika - dodavanjaem vodoravnog okreta na svim trening slikama (skripta: flipper.py)</p>

# %% [markdown]
# <p>Uvoženje potrebnih modula:</p>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <p>Postavljanje direktorija sa trening i validacijskim slikama:</p>

# %%
# Postavi direktorije slika
train_dir = "Projekt_slike_128/Trening"
test_dir = "Projekt_slike_128/Validacija"

# %% [markdown]
# <p>Odabir broja epoha i veličine batch-eva:</p>

# %%
# Odredi broj epoha i veličinu batcheva
num_of_epochs = input("Number of epochs:")
num_of_epochs = int(num_of_epochs)
size_of_batch = input("Batch size:")
size_of_batch = int(size_of_batch)
# Out:
# Number of epochs: 20
# Batch size: 128

# %% [markdown]
# <p>Generiranje podataka:</p>

# %%
# Generatori podataka
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(128, 128), batch_size=size_of_batch, class_mode="categorical"
)

test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=(128, 128), batch_size=size_of_batch, class_mode="categorical"
)
# Out:
# Found 4200 images belonging to 3 classes.
# Found 750 images belonging to 3 classes.

# %% [markdown]
# <p>Prikaz slika iz svake klase: </p>

# %%
# Primjeri slika
def display_sample_images(generator):
    x, y = next(generator)
    plt.figure(figsize=(10, 10))
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(x[i])
        
        if (np.argmax(y[i])==0):
            plt.title("mala")
        if (np.argmax(y[i])==1):
            plt.title("srednja")
        if (np.argmax(y[i])==2):
            plt.title("velika")
        plt.axis("off")
    plt.show()


display_sample_images(train_generator)

# %% [markdown]
# <p>Jednostavnosti radi, veličine šalica nazvanje su mala, srednja i velika.
# Srednja šalica je "velika šalica za crnu kavu", a velika šalica je "šalica za bijelu kavu".</p>

# %% [markdown]
# <hr/>
# <p>Izgradnja osnovnog CNN modela za prepoznavanje šalica:</p>

# %%
# CNN model
model = Sequential(
    [
        Conv2D(32, (3, 3), activation="relu", input_shape=(128, 128, 3)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation="relu"),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation="relu"),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation="relu"),
        Dense(3, activation="softmax"),
    ]
)
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_18 (MaxPooli  (None, 63, 63, 32)        0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_19 (MaxPooli  (None, 30, 30, 64)        0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_20 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 25088)             0
#
#  dense_12 (Dense)            (None, 512)               12845568
#
#  dense_13 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 12940355 (49.36 MB)
# Trainable params: 12940355 (49.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# <p>Kompajliranje i treniranje modela</p>

# %% [markdown]
# <hr/>
# <h2>MOdel B.1</h2>
# <p>broj epoha: 20</p>
# <p>veličina batch-a:64</p>

# %%
# Kompajliranje
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Treniranje
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=num_of_epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // test_generator.batch_size,
)
# Out:
# Epoch 1/20
# 65/65 [==============================] - 38s 519ms/step - loss: 0.6431 - accuracy: 0.7307 - val_loss: 0.9001 - val_accuracy: 0.6023
# Epoch 2/20
# 65/65 [==============================] - 33s 506ms/step - loss: 0.4125 - accuracy: 0.8368 - val_loss: 0.9654 - val_accuracy: 0.6151
# Epoch 3/20
# 65/65 [==============================] - 33s 509ms/step - loss: 0.2697 - accuracy: 0.8985 - val_loss: 1.3020 - val_accuracy: 0.6151
# Epoch 4/20
# 65/65 [==============================] - 33s 506ms/step - loss: 0.2049 - accuracy: 0.9243 - val_loss: 1.8652 - val_accuracy: 0.5327
# Epoch 5/20
# 65/65 [==============================] - 33s 509ms/step - loss: 0.1160 - accuracy: 0.9579 - val_loss: 1.8871 - val_accuracy: 0.5668
# Epoch 6/20
# 65/65 [==============================] - 33s 507ms/step - loss: 0.0611 - accuracy: 0.9819 - val_loss: 3.0831 - val_accuracy: 0.5355
# Epoch 7/20
# 65/65 [==============================] - 33s 510ms/step - loss: 0.0265 - accuracy: 0.9942 - val_loss: 3.7042 - val_accuracy: 0.4986
# Epoch 8/20
# 65/65 [==============================] - 33s 506ms/step - loss: 0.0573 - accuracy: 0.9826 - val_loss: 2.8283 - val_accuracy: 0.5341
# Epoch 9/20
# 65/65 [==============================] - 33s 508ms/step - loss: 0.0304 - accuracy: 0.9915 - val_loss: 3.3635 - val_accuracy: 0.5270
# Epoch 10/20
# 65/65 [==============================] - 33s 506ms/step - loss: 0.0344 - accuracy: 0.9906 - val_loss: 2.8155 - val_accuracy: 0.5767
# Epoch 11/20
# 65/65 [==============================] - 33s 509ms/step - loss: 0.0491 - accuracy: 0.9845 - val_loss: 3.4795 - val_accuracy: 0.4886
# Epoch 12/20
# 65/65 [==============================] - 33s 506ms/step - loss: 0.0174 - accuracy: 0.9952 - val_loss: 4.1071 - val_accuracy: 0.5355
# Epoch 13/20
# 65/65 [==============================] - 33s 509ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 4.6685 - val_accuracy: 0.5043
# Epoch 14/20
# 65/65 [==============================] - 33s 506ms/step - loss: 0.0467 - accuracy: 0.9853 - val_loss: 4.2764 - val_accuracy: 0.5355
# Epoch 15/20
# 65/65 [==============================] - 33s 508ms/step - loss: 0.0266 - accuracy: 0.9923 - val_loss: 4.1299 - val_accuracy: 0.5270
# Epoch 16/20
# 65/65 [==============================] - 33s 507ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 3.7394 - val_accuracy: 0.5227
# Epoch 17/20
# 65/65 [==============================] - 33s 509ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 4.3840 - val_accuracy: 0.5298
# Epoch 18/20
# 65/65 [==============================] - 33s 505ms/step - loss: 5.5455e-04 - accuracy: 1.0000 - val_loss: 4.6190 - val_accuracy: 0.5384
# Epoch 19/20
# 65/65 [==============================] - 33s 507ms/step - loss: 3.3199e-04 - accuracy: 1.0000 - val_loss: 4.8836 - val_accuracy: 0.5298
# Epoch 20/20
# 65/65 [==============================] - 33s 506ms/step - loss: 2.3371e-04 - accuracy: 1.0000 - val_loss: 4.9005 - val_accuracy: 0.5369

# %% [markdown]
# <hr/>
# <p>Plot točnosti i gubitka, </p>
# <p>Evaluacija modela B.1:</p>

# %%
# Plot točnosti treninga i validacije
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc="upper left")

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc="upper left")
plt.show()



# Evaluacija modela
test_loss, test_acc = model.evaluate(
    test_generator, steps=test_generator.samples // test_generator.batch_size
)
print("Test accuracy:", test_acc)
# Out:
# 11/11 [==============================] - 2s 159ms/step - loss: 4.9737 - accuracy: 0.5369
# Test accuracy: 0.5369318127632141

# %% [markdown]
# <hr/>
# <h2>MOdel B.2</h2>
# <p>broj epoha: 50</p>
# <p>veličina batch-a:64</p>

# %%
# Kompajliranje
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Treniranje
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=num_of_epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // test_generator.batch_size,
)
# Out:
# Epoch 1/50
# 65/65 [==============================] - 38s 517ms/step - loss: 1.0937 - accuracy: 0.4681 - val_loss: 1.0459 - val_accuracy: 0.4702
# Epoch 2/50
# 65/65 [==============================] - 32s 495ms/step - loss: 0.7288 - accuracy: 0.6806 - val_loss: 1.0025 - val_accuracy: 0.5085
# Epoch 3/50
# 65/65 [==============================] - 33s 511ms/step - loss: 0.5004 - accuracy: 0.7991 - val_loss: 1.0418 - val_accuracy: 0.5469
# Epoch 4/50
# 65/65 [==============================] - 32s 495ms/step - loss: 0.3434 - accuracy: 0.8711 - val_loss: 1.8640 - val_accuracy: 0.5611
# Epoch 5/50
# 65/65 [==============================] - 33s 508ms/step - loss: 0.2692 - accuracy: 0.8977 - val_loss: 1.6805 - val_accuracy: 0.5810
# Epoch 6/50
# 65/65 [==============================] - 32s 497ms/step - loss: 0.1698 - accuracy: 0.9379 - val_loss: 1.6742 - val_accuracy: 0.5668
# Epoch 7/50
# 65/65 [==============================] - 33s 508ms/step - loss: 0.1158 - accuracy: 0.9618 - val_loss: 2.7686 - val_accuracy: 0.5284
# Epoch 8/50
# 65/65 [==============================] - 32s 495ms/step - loss: 0.0868 - accuracy: 0.9681 - val_loss: 3.2001 - val_accuracy: 0.5540
# Epoch 9/50
# 65/65 [==============================] - 33s 508ms/step - loss: 0.0807 - accuracy: 0.9768 - val_loss: 3.1595 - val_accuracy: 0.5355
# Epoch 10/50
# 65/65 [==============================] - 32s 496ms/step - loss: 0.0726 - accuracy: 0.9746 - val_loss: 3.1682 - val_accuracy: 0.5696
# Epoch 11/50
# 65/65 [==============================] - 33s 508ms/step - loss: 0.0232 - accuracy: 0.9942 - val_loss: 4.3328 - val_accuracy: 0.5554
# Epoch 12/50
# 65/65 [==============================] - 32s 495ms/step - loss: 0.0117 - accuracy: 0.9985 - val_loss: 4.1059 - val_accuracy: 0.5810
# Epoch 13/50
# 65/65 [==============================] - 33s 509ms/step - loss: 0.0052 - accuracy: 0.9998 - val_loss: 4.5416 - val_accuracy: 0.5824
# Epoch 14/50
# 65/65 [==============================] - 32s 496ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 5.0604 - val_accuracy: 0.5625
# Epoch 15/50
# 65/65 [==============================] - 33s 509ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.3124 - val_accuracy: 0.5653
# Epoch 16/50
# 65/65 [==============================] - 32s 496ms/step - loss: 9.8461e-04 - accuracy: 1.0000 - val_loss: 5.4281 - val_accuracy: 0.5795
# Epoch 17/50
# 65/65 [==============================] - 33s 509ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 5.3582 - val_accuracy: 0.5739
# Epoch 18/50
# 65/65 [==============================] - 32s 496ms/step - loss: 5.4779e-04 - accuracy: 1.0000 - val_loss: 5.5916 - val_accuracy: 0.5625
# Epoch 19/50
# 65/65 [==============================] - 34s 513ms/step - loss: 4.3203e-04 - accuracy: 1.0000 - val_loss: 6.0071 - val_accuracy: 0.5625
# Epoch 20/50
# 65/65 [==============================] - 33s 500ms/step - loss: 3.5288e-04 - accuracy: 1.0000 - val_loss: 5.8810 - val_accuracy: 0.5668
# Epoch 21/50
# 65/65 [==============================] - 33s 511ms/step - loss: 2.9671e-04 - accuracy: 1.0000 - val_loss: 6.0192 - val_accuracy: 0.5739
# Epoch 22/50
# 65/65 [==============================] - 33s 500ms/step - loss: 2.5215e-04 - accuracy: 1.0000 - val_loss: 6.0162 - val_accuracy: 0.5639
# Epoch 23/50
# 65/65 [==============================] - 34s 513ms/step - loss: 2.1481e-04 - accuracy: 1.0000 - val_loss: 6.3213 - val_accuracy: 0.5639
# Epoch 24/50
# 65/65 [==============================] - 33s 499ms/step - loss: 2.0376e-04 - accuracy: 1.0000 - val_loss: 6.4195 - val_accuracy: 0.5639
# Epoch 25/50
# 65/65 [==============================] - 33s 512ms/step - loss: 1.8098e-04 - accuracy: 1.0000 - val_loss: 6.4166 - val_accuracy: 0.5597
# Epoch 26/50
# 65/65 [==============================] - 33s 500ms/step - loss: 1.5314e-04 - accuracy: 1.0000 - val_loss: 6.3792 - val_accuracy: 0.5682
# Epoch 27/50
# 65/65 [==============================] - 33s 512ms/step - loss: 1.4170e-04 - accuracy: 1.0000 - val_loss: 6.6435 - val_accuracy: 0.5668
# Epoch 28/50
# 65/65 [==============================] - 33s 501ms/step - loss: 1.2213e-04 - accuracy: 1.0000 - val_loss: 6.6892 - val_accuracy: 0.5668
# Epoch 29/50
# 65/65 [==============================] - 33s 509ms/step - loss: 1.1470e-04 - accuracy: 1.0000 - val_loss: 6.8762 - val_accuracy: 0.5639
# Epoch 30/50
# 65/65 [==============================] - 32s 496ms/step - loss: 1.0123e-04 - accuracy: 1.0000 - val_loss: 6.7115 - val_accuracy: 0.5696
# Epoch 31/50
# 65/65 [==============================] - 33s 509ms/step - loss: 9.7263e-05 - accuracy: 1.0000 - val_loss: 6.6540 - val_accuracy: 0.5668
# Epoch 32/50
# 65/65 [==============================] - 32s 496ms/step - loss: 8.4922e-05 - accuracy: 1.0000 - val_loss: 6.8970 - val_accuracy: 0.5639
# Epoch 33/50
# 65/65 [==============================] - 33s 508ms/step - loss: 7.8666e-05 - accuracy: 1.0000 - val_loss: 6.8283 - val_accuracy: 0.5582
# Epoch 34/50
# 65/65 [==============================] - 33s 498ms/step - loss: 7.3427e-05 - accuracy: 1.0000 - val_loss: 6.9164 - val_accuracy: 0.5696
# Epoch 35/50
# 65/65 [==============================] - 33s 510ms/step - loss: 6.7399e-05 - accuracy: 1.0000 - val_loss: 7.0421 - val_accuracy: 0.5696
# Epoch 36/50
# 65/65 [==============================] - 32s 497ms/step - loss: 6.2112e-05 - accuracy: 1.0000 - val_loss: 6.7756 - val_accuracy: 0.5710
# Epoch 37/50
# 65/65 [==============================] - 33s 510ms/step - loss: 5.7563e-05 - accuracy: 1.0000 - val_loss: 6.9810 - val_accuracy: 0.5625
# Epoch 38/50
# 65/65 [==============================] - 32s 497ms/step - loss: 5.1856e-05 - accuracy: 1.0000 - val_loss: 7.0258 - val_accuracy: 0.5724
# Epoch 39/50
# 65/65 [==============================] - 33s 509ms/step - loss: 4.8471e-05 - accuracy: 1.0000 - val_loss: 7.1076 - val_accuracy: 0.5682
# Epoch 40/50
# 65/65 [==============================] - 32s 496ms/step - loss: 4.6231e-05 - accuracy: 1.0000 - val_loss: 7.1120 - val_accuracy: 0.5611
# Epoch 41/50
# 65/65 [==============================] - 33s 509ms/step - loss: 4.3332e-05 - accuracy: 1.0000 - val_loss: 7.0736 - val_accuracy: 0.5710
# Epoch 42/50
# 65/65 [==============================] - 32s 497ms/step - loss: 4.1044e-05 - accuracy: 1.0000 - val_loss: 7.1921 - val_accuracy: 0.5625
# Epoch 43/50
# 65/65 [==============================] - 33s 509ms/step - loss: 3.7544e-05 - accuracy: 1.0000 - val_loss: 7.1551 - val_accuracy: 0.5639
# Epoch 44/50
# 65/65 [==============================] - 32s 497ms/step - loss: 3.5206e-05 - accuracy: 1.0000 - val_loss: 7.0775 - val_accuracy: 0.5739
# Epoch 45/50
# 65/65 [==============================] - 33s 509ms/step - loss: 3.2734e-05 - accuracy: 1.0000 - val_loss: 7.0517 - val_accuracy: 0.5739
# Epoch 46/50
# 65/65 [==============================] - 32s 496ms/step - loss: 3.0375e-05 - accuracy: 1.0000 - val_loss: 7.1588 - val_accuracy: 0.5682
# Epoch 47/50
# 65/65 [==============================] - 34s 522ms/step - loss: 2.7865e-05 - accuracy: 1.0000 - val_loss: 7.1222 - val_accuracy: 0.5767
# Epoch 48/50
# 65/65 [==============================] - 32s 496ms/step - loss: 2.5670e-05 - accuracy: 1.0000 - val_loss: 7.1921 - val_accuracy: 0.5696
# Epoch 49/50
# 65/65 [==============================] - 33s 509ms/step - loss: 2.4422e-05 - accuracy: 1.0000 - val_loss: 7.4091 - val_accuracy: 0.5682
# Epoch 50/50
# 65/65 [==============================] - 32s 497ms/step - loss: 2.3743e-05 - accuracy: 1.0000 - val_loss: 7.3524 - val_accuracy: 0.5625

# %% [markdown]
# <hr/>
# <p>Plot točnosti i gubitka, </p>
# <p>Evaluacija modela B.2:</p>

# %%
# Plot točnosti treninga i validacije
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc="upper left")

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc="upper left")
plt.show()



# Evaluacija modela
test_loss, test_acc = model.evaluate(
    test_generator, steps=test_generator.samples // test_generator.batch_size
)
print("Test accuracy:", test_acc)
# Out:
# 11/11 [==============================] - 2s 159ms/step - loss: 7.1794 - accuracy: 0.5696
# Test accuracy: 0.5696022510528564

# %% [markdown]
# <hr/>
# <h2>MOdel B.3</h2>
# <p>broj epoha: 20</p>
# <p>veličina batch-a:128</p>

# %%
# Kompajliranje
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Treniranje
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=num_of_epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // test_generator.batch_size,
)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 37s 1s/step - loss: 1.1848 - accuracy: 0.4479 - val_loss: 1.0440 - val_accuracy: 0.4734
# Epoch 2/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.7564 - accuracy: 0.6540 - val_loss: 1.0461 - val_accuracy: 0.4469
# Epoch 3/20
# 32/32 [==============================] - 33s 1s/step - loss: 0.6433 - accuracy: 0.7252 - val_loss: 1.3346 - val_accuracy: 0.4797
# Epoch 4/20
# 32/32 [==============================] - 32s 988ms/step - loss: 0.4697 - accuracy: 0.8087 - val_loss: 1.4351 - val_accuracy: 0.4922
# Epoch 5/20
# 32/32 [==============================] - 33s 1s/step - loss: 0.4850 - accuracy: 0.8055 - val_loss: 1.5301 - val_accuracy: 0.5484
# Epoch 6/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.3688 - accuracy: 0.8554 - val_loss: 1.3060 - val_accuracy: 0.5781
# Epoch 7/20
# 32/32 [==============================] - 31s 976ms/step - loss: 0.2840 - accuracy: 0.8912 - val_loss: 1.1771 - val_accuracy: 0.5813
# Epoch 8/20
# 32/32 [==============================] - 33s 1s/step - loss: 0.2219 - accuracy: 0.9111 - val_loss: 1.9141 - val_accuracy: 0.5703
# Epoch 9/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.1833 - accuracy: 0.9315 - val_loss: 1.7196 - val_accuracy: 0.5594
# Epoch 10/20
# 32/32 [==============================] - 33s 1s/step - loss: 0.1971 - accuracy: 0.9285 - val_loss: 2.3417 - val_accuracy: 0.5422
# Epoch 11/20
# 32/32 [==============================] - 32s 985ms/step - loss: 0.1008 - accuracy: 0.9664 - val_loss: 2.2651 - val_accuracy: 0.5734
# Epoch 12/20
# 32/32 [==============================] - 33s 1s/step - loss: 0.0695 - accuracy: 0.9772 - val_loss: 2.4863 - val_accuracy: 0.5531
# Epoch 13/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.0475 - accuracy: 0.9872 - val_loss: 2.5965 - val_accuracy: 0.5828
# Epoch 14/20
# 32/32 [==============================] - 33s 1s/step - loss: 0.0342 - accuracy: 0.9904 - val_loss: 2.9198 - val_accuracy: 0.5766
# Epoch 15/20
# 32/32 [==============================] - 31s 953ms/step - loss: 0.0838 - accuracy: 0.9735 - val_loss: 2.2953 - val_accuracy: 0.5703
# Epoch 16/20
# 32/32 [==============================] - 33s 1s/step - loss: 0.1407 - accuracy: 0.9516 - val_loss: 2.4593 - val_accuracy: 0.5625
# Epoch 17/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.0410 - accuracy: 0.9882 - val_loss: 2.6071 - val_accuracy: 0.5688
# Epoch 18/20
# 32/32 [==============================] - 31s 970ms/step - loss: 0.0396 - accuracy: 0.9882 - val_loss: 2.8373 - val_accuracy: 0.5875
# Epoch 19/20
# 32/32 [==============================] - 33s 1s/step - loss: 0.0179 - accuracy: 0.9968 - val_loss: 3.1740 - val_accuracy: 0.6094
# Epoch 20/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.0095 - accuracy: 0.9980 - val_loss: 3.1050 - val_accuracy: 0.6031

# %% [markdown]
# <hr/>
# <p>Plot točnosti i gubitka, </p>
# <p>Evaluacija modela B.3:</p>

# %%
# Plot točnosti treninga i validacije
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc="upper left")

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Validation"], loc="upper left")
plt.show()



# Evaluacija modela
test_loss, test_acc = model.evaluate(
    test_generator, steps=test_generator.samples // test_generator.batch_size
)
print("Test accuracy:", test_acc)
# Out:
# 5/5 [==============================] - 2s 275ms/step - loss: 2.9111 - accuracy: 0.6078
# Test accuracy: 0.6078125238418579

# %% [markdown]
# <hr/>
# <h2>Zaključak:</h2>
# <p>POvećanje broja slika u terningu na 1400 po klasi i 250 po validaciji nije donijelo značajnija poboljšanja. Model je overfittan, a točnost iako daleko bolja od modela_0, je tek marginalno bolja od modela_alfa. Kompleksonst modela (preko 12000000 parametara) utječe na overfitting.</p>
# <p> Sljedeći korak: <ul><li>vratiti set slika na 700/100 po klasi</li><li>pojednostavniti početni model, drastično smanjiti broj parametara</li></ul> </p>
